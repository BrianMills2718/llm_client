# %% [markdown]
# # Plan 27: Direct Gemini Thinking Budget Policy
#
# ## Goal
#
# Replace the hardcoded direct-Gemini `budget_tokens=0` default with a shared configurable policy backed by Plan 26 live evidence.
#
# ## Inputs
#
# - Direct Gemini model IDs such as `gemini/gemini-2.5-pro`
# - Existing caller kwargs, including optional explicit `thinking`
# - Shared `ClientConfig` and environment defaults
#
# ## Outputs
#
# - Provider kwargs with the correct `thinking` payload for direct Gemini models
# - Tests proving config override, disable path, and caller override behavior
#
# ## Acceptance
#
# - No hardcoded direct-Gemini zero-budget default remains
# - Direct Gemini succeeds in the live schema study without the study-only override
