# %% [markdown]
# # OpenRouter Gemini 3.1 Pro Registry And Tyler Validation
#
# Canonical plan: `docs/plans/28_openrouter-gemini31-pro-registry-and-tyler-validation.md`

# %% [markdown]
# ## Goal
#
# Add `openrouter/google/gemini-3.1-pro-preview` to the shared model registry and validate it on Tyler-like structured-output cases.
